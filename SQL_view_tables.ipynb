# %%
import pandas as pd

# %%
from google.colab import files
import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # View table for average customer rating

# %%
Avg_Customer_Rating = pd.read_csv('/content/Average customer rating.csv')
Avg_Customer_Rating
# Out:
#   Vehicle_Type  avg_customer_rating
# 0  Prime Sedan             3.999649
# 1         Bike             3.992311
# 2    Prime SUV             3.997571
# 3        eBike             3.987962
# 4         Mini             3.997829
# 5   Prime Plus             4.008274
# 6         Auto             3.997571

# %% [markdown]
#  # View table for cancelled customer rides

# %%
cancelled_customer_rides = pd.read_csv('/content/Cancelled customer rides.csv')
cancelled_customer_rides
# Out:
#    Canceled_Rides_by_Customer
# 0                        6953

# %% [markdown]
# # View table for average ride distance

# %%
avg_ride_distance = pd.read_csv('/content/average ride distance for each vehicle.csv')
avg_ride_distance
# Out:
#   Vehicle_Type  avg_distance
# 0  Prime Sedan       15.7573
# 1         Bike       15.7150
# 2    Prime SUV       15.1608
# 3        eBike       15.6472
# 4         Mini       15.5732
# 5   Prime Plus       15.3796
# 6         Auto        6.2120

# %% [markdown]
# # View table for incomplete rides reason

# %%
incomplete_rides_reason = pd.read_csv('/content/incomplete rides reason.csv')
incomplete_rides_reason
# Out:
#         Booking_ID Incomplete_Rides_Reason
# 0    CNR5176704322         Customer Demand
# 1    CNR9312632867       Vehicle Breakdown
# 2    CNR7924302885         Customer Demand
# 3    CNR1640228587             Other Issue
# 4    CNR7623690602             Other Issue
# ..             ...                     ...
# 995  CNR4673178948         Customer Demand
# 996  CNR7650004479         Customer Demand
# 997  CNR7844065781       Vehicle Breakdown
# 998  CNR7454830754         Customer Demand
# 999  CNR1033318953         Customer Demand
#
# [1000 rows x 2 columns]

# %% [markdown]
# # View table for maximum and minimum driver rating

# %%
max_min_driver_rating = pd.read_csv('/content/max min driver rating.csv')
max_min_driver_rating
# Out:
#    max_rating  min_rating
# 0           5           3

# %% [markdown]
# # View table for rides cancelled by drivers

# %%
rides_cancelled_drivers = pd.read_csv('/content/rides_cancelled_by_drivers_p_c_issues.csv')
rides_cancelled_drivers
# Out:
#    COUNT(*)
# 0      4278

# %% [markdown]
# # View table for successful bookings

# %%
successful_bookings = pd.read_csv('/content/successful_bookings.csv')
successful_bookings
# Out:
#                     Date      Time     Booking_ID Booking_Status Customer_ID  \
# 0    2024-07-25 22:20:00  22:20:00  CNR2940424040        Success   CID225428
# 1    2024-07-30 19:59:00  19:59:00  CNR2982357879        Success   CID270156
# 2     2024-07-02 9:02:00  09:02:00  CNR1797421769        Success   CID939555
# 3     2024-07-13 4:42:00  04:42:00  CNR8787177882        Success   CID802429
# 4     2024-07-23 9:51:00  09:51:00  CNR3612067560        Success   CID476071
# ..                   ...       ...            ...            ...         ...
# 995  2024-07-19 11:14:00  11:14:00  CNR7825991393        Success   CID191260
# 996  2024-07-06 11:24:00  11:24:00  CNR9467197030        Success   CID445711
# 997  2024-07-07 15:23:00  15:23:00  CNR8947815950        Success   CID237025
# 998  2024-07-27 15:15:00  15:15:00  CNR9133360081        Success   CID874364
# 999   2024-07-13 9:56:00  09:56:00  CNR4743708122        Success   CID527208
#
# ...

# %% [markdown]
# # View table for top 5 customers

# %%
top5_customers = pd.read_csv('/content/top_5_customers.csv')
top5_customers
# Out:
#   Customer_ID  total_rides
# 0   CID340854            4
# 1   CID558349            3
# 2   CID989500            3
# 3   CID152855            3
# 4   CID275322            3

# %% [markdown]
# # View table for total successful ride revenue

# %%
total_successful_ride_revenue = pd.read_csv('/content/total_successful_ride_value.csv')
total_successful_ride_revenue
# Out:
#    total_successful_ride_value
# 0                     23365156

# %% [markdown]
# # View table for payments made through UPI

# %%
payments_made_upi = pd.read_csv('/content/upi_payment.csv')
payments_made_upi
# Out:
#                     Date      Time     Booking_ID Booking_Status Customer_ID  \
# 0    2024-07-30 19:59:00  19:59:00  CNR2982357879        Success   CID270156
# 1     2024-07-13 4:42:00  04:42:00  CNR8787177882        Success   CID802429
# 2    2024-07-27 13:18:00  13:18:00  CNR4524472111        Success   CID540929
# 3     2024-07-16 9:54:00  09:54:00  CNR8181602032        Success   CID167642
# 4    2024-07-02 10:25:00  10:25:00  CNR8090918544        Success   CID640151
# ..                   ...       ...            ...            ...         ...
# 995   2024-07-09 8:27:00  08:27:00  CNR2385231219        Success   CID205220
# 996   2024-07-28 1:34:00  01:34:00  CNR1693894972        Success   CID683760
# 997  2024-07-19 12:13:00  12:13:00  CNR8732659411        Success   CID784135
# 998  2024-07-25 21:27:00  21:27:00  CNR2969144460        Success   CID531876
# 999  2024-07-06 15:09:00  15:09:00  CNR5231197011        Success   CID337900
#
# ...
